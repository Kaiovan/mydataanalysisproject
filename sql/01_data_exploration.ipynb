# %%
import sys
sys.path.append('/app')

# %%
from src.data_generation.clickstream_generator import main as generate_data
generate_data()
# Out:
# Starting clickstream data generation...
# Generating 10000 sessions...
# Generated 1000/10000 sessions...
# Generated 2000/10000 sessions...
# Generated 3000/10000 sessions...
# Generated 4000/10000 sessions...
# Generated 5000/10000 sessions...
# Generated 6000/10000 sessions...
# Generated 7000/10000 sessions...
# Generated 8000/10000 sessions...
# Generated 9000/10000 sessions...
# Generated 10000/10000 sessions...
# Generated 114550 total events
# Saved 114550 events to /app/data/raw/clickstream_events.csv
# Saved 114550 events to /app/data/raw/clickstream_events.jsonl
#
# Generating product catalog...
# Saved 500 products to product_catalog.csv
#
# Data generation complete!

# %%
from src.spark_processing.etl_pipeline import main as run_etl
run_etl()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/02 08:48:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark version: 3.5.0
# Spark UI available at: http://764d21e64dee:4040
# ...
# STARTING CLICKSTREAM ETL PIPELINE
# ...
#
# Reading clickstream data from /app/data/raw/clickstream_events.csv...
# Loaded 114,550 events
#
# Schema:
# root
#  |-- browser: string (nullable = true)
#  |-- cart_size: integer (nullable = true)
#  |-- cart_value: double (nullable = true)
#  |-- category: string (nullable = true)
#  |-- device: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- ip_address: string (nullable = true)
#  |-- num_items: integer (nullable = true)
#  |-- page_type: string (nullable = true)
#  |-- payment_method: string (nullable = true)
# ...
